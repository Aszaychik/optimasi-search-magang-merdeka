# %% [markdown]
# # **Sistem Rekomendasi Pencarian Magang Merdeka Content Based Filtering**

# %% [markdown]
# ## **Data Scraping**

# %%
import requests
import pandas as pd

# %%
url_opportunities = "https://api.kampusmerdeka.kemdikbud.go.id/magang/browse/opportunities"
url_detail = "https://api.kampusmerdeka.kemdikbud.go.id/magang/browse/opportunities/{}"
url_mitra = "https://api.kampusmerdeka.kemdikbud.go.id/mitra/public/id/{}"
limit = 100
offset = 0

all_data = pd.DataFrame()

while True:
    params = {
        "offset": offset,
        "limit": limit,
        "location_key": "",
        "mitra_key": "",
        "keyword": "",
        "sector_id": "",
        "sort_by": "",
        "order": "desc"
    }

    response = requests.get(url_opportunities, params=params)

    offset += limit
    data = response.json()["data"]
    if len(data) == 0:
        break

    # Mengupulkan detail data setiap id entry
    for entry_id in data:
        detail_url = url_detail.format(entry_id["id"])
        mitra_url = url_mitra.format(entry_id["mitra_id"])

        detail_response = requests.get(detail_url)
        mitra_url_response = requests.get(mitra_url)

        mitra_data = pd.json_normalize(mitra_url_response.json())
        detail_data = pd.json_normalize(detail_response.json())

        # Menghilangkan prefix "data." dan "benefits."
        mitra_data.columns = [col.replace("data.", "") for col in mitra_data.columns]
        detail_data.columns = [col.replace("data.", "").replace("benefits.", "") for col in detail_data.columns]

        detail_data['mitra_name'] = mitra_data['name']

        all_data = pd.concat([all_data, detail_data], ignore_index=True)

    print(f"Data collected: {len(all_data)}")

print(f"Total {len(all_data)} data collected")

# %%
all_data

# %%
all_data.to_csv('magang_opportunities.csv', index=False)

# %% [markdown]
# ## **Data PreProcessing**

# %% [markdown]
# ### **Data Reviewing**

# %%
import pandas as pd

# %%
magang_opportunities = pd.read_csv('magang_opportunities.csv')

magang_opportunities.head()
# Out:
#    meta                                    id                            name  \
# 0   NaN  b794e1a1-ecd6-449d-9ed9-0118a2e02626               Website Developer
# 1   NaN  7c8623ef-5f9b-470d-bc7a-73b1dd706c8b       Software Architect Intern
# 2   NaN  bd95c730-b157-4fc5-8791-9dc9ea5e0e32        Product Marketing Intern
# 3   NaN  fc01895c-0d74-4874-a8f2-d1d46956d697                 Asisten Finance
# 4   NaN  b6062e51-4764-474c-a2b7-617affd56959  Marketing Asuransi Mini Mikro
#
#                                          description  \
# 0  <p><strong>Kualifikasi :</strong>&nbsp;</p><ul...
# 1  <p>To help architect team on demonstration of ...
# 2  <p>- Design and develop sharepoint page to sup...
# 3  <ol><li>Pemahaman Sistem Keuangan Sekolah: And...
# 4  <p>WFH dari Seluruh Indonesia.</p><p><br></p><...
#
#                                mitra_id               start_period  \
# 0  c7746ff1-87de-47bb-a43f-6d63f521e07c  2024-03-01T00:00:00+07:00
# 1  af00bd20-3ac2-44a4-877f-af4307f9b599  2024-03-01T00:00:00+07:00
# 2  af00bd20-3ac2-44a4-877f-af4307f9b599  2024-03-01T00:00:00+07:00
# 3  0bf5a4d1-9980-48ae-ad65-48e3b239f15c  2024-03-01T00:00:00+07:00
# 4  6bbc729e-c3ee-46a1-93be-2b9f3b5f478d  2024-03-01T00:00:00+07:00
#
#    months_duration activity_type              location  \
# 0                3           WFH         Kota Surabaya
# 1                6           WFO  Kota Jakarta Selatan
# 2                6           WFO  Kota Jakarta Selatan
# 3                4           WFO       Kota Banda Aceh
# 4                4           WFH       Kota Banda Aceh
#
#                             fields_of_study  ...  show_salary  mobilization  \
# 0                                        []  ...        False         False
# 1  ['Teknik Informatika dan Ilmu Komputer']  ...        False         False
# 2  ['Teknik Informatika dan Ilmu Komputer']  ...        False         False
# 3                                        []  ...        False         False
# 4                                        []  ...        False         False
#
#   accommodation is_applied  wishlist  is_external  external_platform_name  \
# 0         False      False     False        False                     NaN
# 1         False      False     False        False                     NaN
# 2         False      False     False        False                     NaN
# 3         False      False     False        False                     NaN
# 4         False      False     False        False                     NaN
#
#    external_platform_logo_url                         mitra_name  salary
# 0                         NaN          CV. APPAREL BERKAH SELALU     NaN
# 1                         NaN  PT. Idemia Technologies Indonesia     NaN
# 2                         NaN  PT. Idemia Technologies Indonesia     NaN
# 3                         NaN                 SMAN 14 Banda Aceh     NaN
# 4                         NaN                      Natural Aceh      NaN
#
# [5 rows x 24 columns]

# %%
data = pd.DataFrame({
  'id': list(magang_opportunities['id'].values),
  'name': list(magang_opportunities['name'].values),
  'description': list(magang_opportunities['description'].values),
  'skills': list(magang_opportunities['skills'].values)
})

data
# Out:
#                                        id  \
# 0    b794e1a1-ecd6-449d-9ed9-0118a2e02626
# 1    7c8623ef-5f9b-470d-bc7a-73b1dd706c8b
# 2    bd95c730-b157-4fc5-8791-9dc9ea5e0e32
# 3    fc01895c-0d74-4874-a8f2-d1d46956d697
# 4    b6062e51-4764-474c-a2b7-617affd56959
# ..                                    ...
# 677  7a2f6ef1-844d-4c70-99bc-03be7d5aac88
# 678  404ccd37-0c1e-43ab-bdfd-7b9a6fee551c
# 679  5a704786-6865-40c9-9086-a2bd85dc5098
# 680  780902fd-e51a-463c-a012-e7a0941da47e
# 681  1d00c1ea-95ee-4d24-b5be-63c3ff276bd1
#
#                                                   name  \
# 0                                    Website Developer
# 1                            Software Architect Intern
# 2                             Product Marketing Intern
# 3                                      Asisten Finance
# 4                       Marketing Asuransi Mini Mikro
# ..                                                 ...
# 677                          Marketing Creative Intern
# 678                            Graphic Design (Intern)
# 679                       Influencer Management Intern
# 680  New Business Development Internship (Jakarta U...
# 681                        Finance & Accounting Intern
#
#                                            description  \
# 0    <p><strong>Kualifikasi :</strong>&nbsp;</p><ul...
# 1    <p>To help architect team on demonstration of ...
# 2    <p>- Design and develop sharepoint page to sup...
# 3    <ol><li>Pemahaman Sistem Keuangan Sekolah: And...
# 4    <p>WFH dari Seluruh Indonesia.</p><p><br></p><...
# ..                                                 ...
# 677  Responsibilities \n\nSupport Marketing and Bra...
# 678  Kami Idea merupakan sebuah usaha atau bisnis y...
# 679  - Last semester student from reputable univers...
# 680  - Final year student or fresh graduate \n- Pas...
# 681  Kualifikasi :\n- Mahasiwa aktif, dan freshgrad...
#
#                                                 skills
# 0    ['Komunikasi', 'Kreatif', 'Pemahaman Industri'...
# 1    ['Komunikasi', 'Kreatif', 'Desain Grafis', 'Co...
# 2    ['Kreatif', 'Analisis Data', 'Pemahaman Lingku...
# 3    ['Administrasi', 'Operasional', 'Komunikasi', ...
# 4    ['Operasional', 'Kreatif', 'Administrasi', 'Ko...
# ..                                                 ...
# 677                                                NaN
# 678                                                NaN
# 679                                                NaN
# 680                                                NaN
# 681                                                NaN
#
# [682 rows x 4 columns]

# %% [markdown]
# ### **Combine Text**

# %%
import ast

# %%
# Convert the "skills" column from string to list for non-null values
data['skills'] = data['skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# Join the skills into a single string
data['skills'] = data['skills'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

# Combine "name," "description," and "skills" into a new column
data['combined_text'] = data['name'] + ' ' + data['description'] + ' ' + data['skills'].astype(str)

data['combined_text']
# Out:
# 0      Website Developer <p><strong>Kualifikasi :</st...
# 1      Software Architect Intern <p>To help architect...
# 2      Product Marketing Intern <p>- Design and devel...
# 3      Asisten Finance <ol><li>Pemahaman Sistem Keuan...
# 4      Marketing Asuransi Mini Mikro  <p>WFH dari Sel...
#                              ...
# 677    Marketing Creative Intern Responsibilities \n\...
# 678    Graphic Design (Intern) Kami Idea merupakan se...
# 679    Influencer Management Intern - Last semester s...
# 680    New Business Development Internship (Jakarta U...
# 681    Finance & Accounting Intern Kualifikasi :\n- M...
# Name: combined_text, Length: 682, dtype: object

# %% [markdown]
# ### **Case Folding**

# %%
data['result_case_folding_data'] = data['combined_text'].apply(lambda x: x.casefold())
data[['id', 'combined_text','result_case_folding_data']]
# Out:
#                                        id  \
# 0    b794e1a1-ecd6-449d-9ed9-0118a2e02626
# 1    7c8623ef-5f9b-470d-bc7a-73b1dd706c8b
# 2    bd95c730-b157-4fc5-8791-9dc9ea5e0e32
# 3    fc01895c-0d74-4874-a8f2-d1d46956d697
# 4    b6062e51-4764-474c-a2b7-617affd56959
# ..                                    ...
# 677  7a2f6ef1-844d-4c70-99bc-03be7d5aac88
# 678  404ccd37-0c1e-43ab-bdfd-7b9a6fee551c
# 679  5a704786-6865-40c9-9086-a2bd85dc5098
# 680  780902fd-e51a-463c-a012-e7a0941da47e
# 681  1d00c1ea-95ee-4d24-b5be-63c3ff276bd1
#
#                                          combined_text  \
# 0    Website Developer <p><strong>Kualifikasi :</st...
# 1    Software Architect Intern <p>To help architect...
# 2    Product Marketing Intern <p>- Design and devel...
# 3    Asisten Finance <ol><li>Pemahaman Sistem Keuan...
# 4    Marketing Asuransi Mini Mikro  <p>WFH dari Sel...
# ..                                                 ...
# 677  Marketing Creative Intern Responsibilities \n\...
# 678  Graphic Design (Intern) Kami Idea merupakan se...
# 679  Influencer Management Intern - Last semester s...
# 680  New Business Development Internship (Jakarta U...
# 681  Finance & Accounting Intern Kualifikasi :\n- M...
#
#                               result_case_folding_data
# 0    website developer <p><strong>kualifikasi :</st...
# 1    software architect intern <p>to help architect...
# 2    product marketing intern <p>- design and devel...
# 3    asisten finance <ol><li>pemahaman sistem keuan...
# 4    marketing asuransi mini mikro  <p>wfh dari sel...
# ..                                                 ...
# 677  marketing creative intern responsibilities \n\...
# 678  graphic design (intern) kami idea merupakan se...
# 679  influencer management intern - last semester s...
# 680  new business development internship (jakarta u...
# 681  finance & accounting intern kualifikasi :\n- m...
#
# [682 rows x 3 columns]

# %% [markdown]
# ### **Remove Html Tags**

# %%
from lxml import etree

# %%
def remove_html_tags(text):
    parser = etree.HTMLParser()
    tree = etree.fromstring(text, parser)
    return etree.tostring(tree, encoding='unicode', method='text')

data['result_remove_html_tags'] = data['result_case_folding_data'].apply(remove_html_tags)
data[['id', 'result_case_folding_data' ,'result_remove_html_tags']]
# Out:
#                                        id  \
# 0    b794e1a1-ecd6-449d-9ed9-0118a2e02626
# 1    7c8623ef-5f9b-470d-bc7a-73b1dd706c8b
# 2    bd95c730-b157-4fc5-8791-9dc9ea5e0e32
# 3    fc01895c-0d74-4874-a8f2-d1d46956d697
# 4    b6062e51-4764-474c-a2b7-617affd56959
# ..                                    ...
# 677  7a2f6ef1-844d-4c70-99bc-03be7d5aac88
# 678  404ccd37-0c1e-43ab-bdfd-7b9a6fee551c
# 679  5a704786-6865-40c9-9086-a2bd85dc5098
# 680  780902fd-e51a-463c-a012-e7a0941da47e
# 681  1d00c1ea-95ee-4d24-b5be-63c3ff276bd1
#
#                               result_case_folding_data  \
# 0    website developer <p><strong>kualifikasi :</st...
# 1    software architect intern <p>to help architect...
# 2    product marketing intern <p>- design and devel...
# 3    asisten finance <ol><li>pemahaman sistem keuan...
# 4    marketing asuransi mini mikro  <p>wfh dari sel...
# ..                                                 ...
# 677  marketing creative intern responsibilities \n\...
# 678  graphic design (intern) kami idea merupakan se...
# 679  influencer management intern - last semester s...
# 680  new business development internship (jakarta u...
# 681  finance & accounting intern kualifikasi :\n- m...
#
#                                result_remove_html_tags
# 0    website developer kualifikasi : wajib memiliki...
# 1    software architect intern to help architect te...
# 2    product marketing intern - design and develop ...
# 3    asisten finance pemahaman sistem keuangan seko...
# 4    marketing asuransi mini mikro  wfh dari seluru...
# ..                                                 ...
# 677  marketing creative intern responsibilities \n\...
# 678  graphic design (intern) kami idea merupakan se...
# 679  influencer management intern - last semester s...
# 680  new business development internship (jakarta u...
# 681  finance & accounting intern kualifikasi :\n- m...
#
# [682 rows x 3 columns]

# %% [markdown]
# ### **Remove Unicode Character**

# %%
import re

# %%
data['result_remove_unicode_character'] = data['result_remove_html_tags'].apply(lambda x: re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", x))
data[['id', 'result_remove_html_tags', 'result_remove_unicode_character']]
# Out:
#                                        id  \
# 0    b794e1a1-ecd6-449d-9ed9-0118a2e02626
# 1    7c8623ef-5f9b-470d-bc7a-73b1dd706c8b
# 2    bd95c730-b157-4fc5-8791-9dc9ea5e0e32
# 3    fc01895c-0d74-4874-a8f2-d1d46956d697
# 4    b6062e51-4764-474c-a2b7-617affd56959
# ..                                    ...
# 677  7a2f6ef1-844d-4c70-99bc-03be7d5aac88
# 678  404ccd37-0c1e-43ab-bdfd-7b9a6fee551c
# 679  5a704786-6865-40c9-9086-a2bd85dc5098
# 680  780902fd-e51a-463c-a012-e7a0941da47e
# 681  1d00c1ea-95ee-4d24-b5be-63c3ff276bd1
#
#                                result_remove_html_tags  \
# 0    website developer kualifikasi : wajib memiliki...
# 1    software architect intern to help architect te...
# 2    product marketing intern - design and develop ...
# 3    asisten finance pemahaman sistem keuangan seko...
# 4    marketing asuransi mini mikro  wfh dari seluru...
# ..                                                 ...
# 677  marketing creative intern responsibilities \n\...
# 678  graphic design (intern) kami idea merupakan se...
# 679  influencer management intern - last semester s...
# 680  new business development internship (jakarta u...
# 681  finance & accounting intern kualifikasi :\n- m...
#
#                        result_remove_unicode_character
# 0    website developer kualifikasi wajib memiliki l...
# 1    software architect intern to help architect te...
# 2    product marketing intern  design and develop s...
# 3    asisten finance pemahaman sistem keuangan seko...
# 4    marketing asuransi mini mikro  wfh dari seluru...
# ..                                                 ...
# 677  marketing creative intern responsibilities sup...
# 678  graphic design intern kami idea merupakan sebu...
# 679  influencer management intern  last semester st...
# 680  new business development internship jakarta ut...
# 681  finance  accounting intern kualifikasi  mahasi...
#
# [682 rows x 3 columns]

# %% [markdown]
# ### **Tokenization**

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aszay\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data['result_tokenization'] = data['result_remove_unicode_character'].apply(lambda x: word_tokenize(x))
data[['id', 'result_remove_unicode_character', 'result_tokenization']]
# Out:
#                                        id  \
# 0    b794e1a1-ecd6-449d-9ed9-0118a2e02626
# 1    7c8623ef-5f9b-470d-bc7a-73b1dd706c8b
# 2    bd95c730-b157-4fc5-8791-9dc9ea5e0e32
# 3    fc01895c-0d74-4874-a8f2-d1d46956d697
# 4    b6062e51-4764-474c-a2b7-617affd56959
# ..                                    ...
# 677  7a2f6ef1-844d-4c70-99bc-03be7d5aac88
# 678  404ccd37-0c1e-43ab-bdfd-7b9a6fee551c
# 679  5a704786-6865-40c9-9086-a2bd85dc5098
# 680  780902fd-e51a-463c-a012-e7a0941da47e
# 681  1d00c1ea-95ee-4d24-b5be-63c3ff276bd1
#
#                        result_remove_unicode_character  \
# 0    website developer kualifikasi wajib memiliki l...
# 1    software architect intern to help architect te...
# 2    product marketing intern  design and develop s...
# 3    asisten finance pemahaman sistem keuangan seko...
# 4    marketing asuransi mini mikro  wfh dari seluru...
# ..                                                 ...
# 677  marketing creative intern responsibilities sup...
# 678  graphic design intern kami idea merupakan sebu...
# 679  influencer management intern  last semester st...
# 680  new business development internship jakarta ut...
# 681  finance  accounting intern kualifikasi  mahasi...
#
#                                    result_tokenization
# 0    [website, developer, kualifikasi, wajib, memil...
# 1    [software, architect, intern, to, help, archit...
# 2    [product, marketing, intern, design, and, deve...
# 3    [asisten, finance, pemahaman, sistem, keuangan...
# 4    [marketing, asuransi, mini, mikro, wfh, dari, ...
# ..                                                 ...
# 677  [marketing, creative, intern, responsibilities...
# 678  [graphic, design, intern, kami, idea, merupaka...
# 679  [influencer, management, intern, last, semeste...
# 680  [new, business, development, internship, jakar...
# 681  [finance, accounting, intern, kualifikasi, mah...
#
# [682 rows x 3 columns]

# %% [markdown]
# ### **Remove Stopwords**

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aszay\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
indo_stopwords = stopwords.words('indonesian')
eng_stopwords = stopwords.words('english')

list_stopwords = indo_stopwords + eng_stopwords

# %%
def remove_stopwords(text):
    filtered_words = [word for word in text if word not in list_stopwords]
    return filtered_words

# Apply remove_stopwords to the 'result_tokenization' column
data['result_remove_stopwords'] = data['result_tokenization'].apply(remove_stopwords)

# Optionally, join the list of words back into a string if needed
data['result_remove_stopwords'] = data['result_remove_stopwords'].apply(lambda x: ' '.join(x))

data[['id', 'result_tokenization', 'result_remove_stopwords']]
# Out:
#                                        id  \
# 0    b794e1a1-ecd6-449d-9ed9-0118a2e02626
# 1    7c8623ef-5f9b-470d-bc7a-73b1dd706c8b
# 2    bd95c730-b157-4fc5-8791-9dc9ea5e0e32
# 3    fc01895c-0d74-4874-a8f2-d1d46956d697
# 4    b6062e51-4764-474c-a2b7-617affd56959
# ..                                    ...
# 677  7a2f6ef1-844d-4c70-99bc-03be7d5aac88
# 678  404ccd37-0c1e-43ab-bdfd-7b9a6fee551c
# 679  5a704786-6865-40c9-9086-a2bd85dc5098
# 680  780902fd-e51a-463c-a012-e7a0941da47e
# 681  1d00c1ea-95ee-4d24-b5be-63c3ff276bd1
#
#                                    result_tokenization  \
# 0    [website, developer, kualifikasi, wajib, memil...
# 1    [software, architect, intern, to, help, archit...
# 2    [product, marketing, intern, design, and, deve...
# 3    [asisten, finance, pemahaman, sistem, keuangan...
# 4    [marketing, asuransi, mini, mikro, wfh, dari, ...
# ..                                                 ...
# 677  [marketing, creative, intern, responsibilities...
# 678  [graphic, design, intern, kami, idea, merupaka...
# 679  [influencer, management, intern, last, semeste...
# 680  [new, business, development, internship, jakar...
# 681  [finance, accounting, intern, kualifikasi, mah...
#
#                                result_remove_stopwords
# 0    website developer kualifikasi wajib memiliki l...
# 1    software architect intern help architect team ...
# 2    product marketing intern design develop sharep...
# 3    asisten finance pemahaman sistem keuangan seko...
# 4    marketing asuransi mini mikro wfh indonesiapen...
# ..                                                 ...
# 677  marketing creative intern responsibilities sup...
# 678  graphic design intern idea usaha bisnis berger...
# 679  influencer management intern last semester stu...
# 680  new business development internship jakarta ut...
# 681  finance accounting intern kualifikasi mahasiwa...
#
# [682 rows x 3 columns]

# %% [markdown]
# ### **Stemming**

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stem_word(text):
    return stemmer.stem(text)

data['result_stemming'] = data['result_remove_stopwords'].apply(stem_word)

cleaned_data = data[['id', 'result_stemming']].rename(columns={'result_stemming': 'text'})

cleaned_data
# Out:
#                                        id  \
# 0    b794e1a1-ecd6-449d-9ed9-0118a2e02626
# 1    7c8623ef-5f9b-470d-bc7a-73b1dd706c8b
# 2    bd95c730-b157-4fc5-8791-9dc9ea5e0e32
# 3    fc01895c-0d74-4874-a8f2-d1d46956d697
# 4    b6062e51-4764-474c-a2b7-617affd56959
# ..                                    ...
# 677  7a2f6ef1-844d-4c70-99bc-03be7d5aac88
# 678  404ccd37-0c1e-43ab-bdfd-7b9a6fee551c
# 679  5a704786-6865-40c9-9086-a2bd85dc5098
# 680  780902fd-e51a-463c-a012-e7a0941da47e
# 681  1d00c1ea-95ee-4d24-b5be-63c3ff276bd1
#
#                                                   text
# 0    website developer kualifikasi wajib milik lapt...
# 1    software architect intern help architect team ...
# 2    product marketing intern design develop sharep...
# 3    asisten finance paham sistem uang sekolah ajak...
# 4    marketing asuransi mini mikro wfh indonesiapen...
# ..                                                 ...
# 677  marketing creative intern responsibilities sup...
# 678  graphic design intern idea usaha bisnis gerak ...
# 679  influencer management intern last semester stu...
# 680  new business development internship jakarta ut...
# 681  finance accounting intern kualifikasi mahasiwa...
#
# [682 rows x 2 columns]

# %% [markdown]
# ## **Data Weighing**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words=list_stopwords)

tfidf_matrix = tfidf.fit_transform(cleaned_data['text'])

tfidf_matrix.shape

tfidf_matrix
# Out:
# c:\Users\aszay\Developer\search-recommendation-magang-merdeka\.venv\Lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['baiknya', 'berkali', 'kali', 'kurangnya', 'mata', 'olah', 'sekurang', 'setidak', 'tama', 'tidaknya'] not in stop_words.
#   warnings.warn(
# <682x6316 sparse matrix of type '<class 'numpy.float64'>'
# 	with 37150 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## **Data Modelling**

# %% [markdown]
# ### **Setup Model**

# %%
from sklearn.metrics.pairwise import linear_kernel

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

indices = pd.Series(cleaned_data.index, index=cleaned_data['text']).drop_duplicates()

# %% [markdown]
# ### **Setup Function**

# %%
def recommend_magang(search_value, cosine_sim=cosine_sim):
    recommendation = pd.DataFrame(columns=['id', 'name', 'score'])

    # Check if the search_value is in the indices
    if search_value not in indices:
        print(f"'{search_value}' not found in the indices.")
        return recommendation

    # Get the index of the search_value
    idx = indices[search_value]

    # Get the pairwise similarity scores of all items with the search_value
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the items based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar items
    sim_scores = sim_scores[1:11]

    # Get the item indices and names
    magang_indices = [i[0] for i in sim_scores]
    magang_names = magang_opportunities.loc[magang_indices, 'name']

    # Create the recommendation DataFrame
    recommendation['id'] = magang_opportunities.loc[magang_indices, 'id'].tolist()
    recommendation['name'] = magang_names.tolist()
    recommendation['score'] = [score[1] for score in sim_scores]

    return recommendation

# %% [markdown]
# ## **Evaluation**

# %%
# Assuming your recommendation function is already defined
result = recommend_magang('website developer kualifikasi')

if not result.empty:
    print(result)
else:
    print("No recommendations found.")
# Out:
#                                      id  \
# 0  fe263d29-532a-4860-9d91-6ec91e304b50
# 1  fccec0c2-85e4-4d27-ac3b-01b455dfcbfe
# 2  fc000acf-2901-495e-bcc7-427eef1a39ca
# 3  83681309-8513-44ba-8f0d-15fa0ccef9a9
# 4  a8e3a588-a4a9-4995-bb74-9023b17efb3f
# 5  aedf0eb6-a060-4984-8d14-8da0862681cb
# 6  ee681cbf-582a-4dd8-88e3-41079bc5d150
# 7  7a963c8f-9a6c-4d23-accd-d245bc6b1493
# 8  f54f86ef-fa76-44a8-bc20-3415772513ca
# 9  1fe9c603-c8a2-4d8e-8362-846e8a2ce82f
#
#                                       name     score
# 0                      Manajemen Kemitraan  0.220185
# 1  Internship Content Creator & Copywriter  0.177466
# 2                          Content Creator  0.175047
# 3                         Content Creator   0.169300
# 4                          Web Specialist   0.132920
# 5                   Content Maker (Intern)  0.122996
# 6          Social Media Manager Internship  0.117652
# 7              Content Planner/ Strategist  0.117409
# 8                Jr Content Creator Intern  0.116563
# 9                          Content Creator  0.109291

# %%
print(indices.keys())
# Out:
# Index(['website developer kualifikasi wajib milik laptop sendirimampu website landing page sesuai butuh usaha optimasi seomasa magang minimum 3 jam kerja normalharus serta portofoliobenefit sertifikat magangkonversi nilaisistem wfh komunikasi kreatif paham industri manajemen proyek kreativitas kerjasama tim ahli teknologi pasar produk',
#        'software architect intern help architect team demonstration improvement idea work focused determining whether idea turned realitythe improvement might include test optimization test automation framework usage eg test framework design komunikasi kreatif desain grafis coding',
#        'product marketing intern design develop sharepoint page support business operation collaborate team get data sharepoint page support documentation products willing learn new things kreatif analisis data paham lingkung bisnis komunikasi',
#        'asisten finance paham sistem uang sekolah ajak paham sistem uang sekolah proses bayar lapor uang kelola anggaranpencatatan transaksi uang ajar catat transaksi uang hari terima uang sekolah bayar gaji pegawai beli lengkap sekolah bayar tagihanpengelolaan kas libat kelola kas sekolah susun lapor arus kas kece saldo kas akurat catat transaksi kaspenyusunan lapor uang bantu susun lapor uang bulan tahun lapor laba rugi neraca lapor arus kas libat kumpul data kece akurat susun lapor sesuai standar akuntansi berlakupemahaman keluar pasu sekolah ajar sumber dapat sekolah biaya sekolah dana donasi subsidi perintah keluar operasional sekolah bayar gaji staf beli lengkap biaya pelihara gedungberkomunikasi kait interaksi kait guru staf administrasi orang tua siswa eksternal bank vendor bahas uang administrasi sekolahpartisipasi rapat temu hadir rapat temu internal bahas uang administrasi sekolah kontribusi presentasi sesuai bidang andapenyusunan anggar libat susun anggar tahun sekolah libat rencana keluar dapat evaluasi kerja uang periodikpembelajaran sistem perangkat lunak uang sekolah sistem perangkat lunak uang ajar operasi paham fungsifungsi dasar sistem tersebutproyek khusus terkadang tanggung selesai proyek khusus kait uang administrasi sekolah evaluasi efisiensi operasional susun bijak uang implementasi sistem administrasi operasional komunikasi kreatif',
#        'marketing asuransi mini mikro wfh indonesiapenelitian pasar mahasiswa ajak teliti pasar kait produk asuransi mikro tawar usaha liput analis target pasar paham butuh preferensi calon langgan evaluasi saing pasarpengembangan strategi pasar mahasiswa libat proses kembang strategi pasar produk asuransi mikro ajar guna salur pasar promosi komunikasi tingkat sadar minat calon pelangganpenyusunan materi promosi mahasiswa bantu susun materi promosi br